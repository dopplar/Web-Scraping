# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# Creating a webdriver instance
driver_path=""
driver_path = SeleniumManager().driver_location(options) if driver_path is None else driver_path
driver = webdriver.Chrome(driver_path)
# This instance will be used to log into LinkedIn

# Opening linkedIn's login page
driver.get("https://www.linkedin.com/login")

# waiting for the page to load
time.sleep(7)

# entering username
username = driver.find_element(By.ID, "username")

# In case of an error, try changing the element
# tag used here.

# Enter Your Email Address
username.send_keys("******")

# entering password
pword = driver.find_element(By.ID, "password")
# In case of an error, try changing the element
# tag used here.

# Enter Your Password
pword.send_keys("*******")	

# Clicking on the log in button
# Format (syntax) of writing XPath -->
# //tagname[@attribute='value']
driver.find_element(By.XPATH, "//button[@type='submit']").click()

# %%
profile_url = "https://www.linkedin.com/in/sameer-mehta-16233318/?originalSubdomain=in"
 
driver.get(profile_url)        # this will open the link

# %%
start = time.time()
 
# will be used in the while loop
initialScroll = 0
finalScroll = 1000
 
while True:
    driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
    # this command scrolls the window starting from
    # the pixel value stored in the initialScroll
    # variable to the pixel value stored at the
    # finalScroll variable
    initialScroll = finalScroll
    finalScroll += 1000
 
    # we will stop the script for 3 seconds so that
    # the data can load
    time.sleep(3)
    # You can change it as per your needs and internet speed
 
    end = time.time()
 
    # We will scroll for 20 seconds.
    # You can change it as per your needs and internet speed
    if round(end - start) > 20:
        break

# %%
src = driver.page_source

# Now using beautiful soup
soup = BeautifulSoup(src, 'lxml')

# %%
intro = soup.find('div', {'class': 'pv-text-details__left-panel'})
 
print(intro)
# Out:
# <div class="pv-text-details__left-panel">
# <div>
# <h1 class="text-heading-xlarge inline t-24 v-align-middle break-words">Sameer Mehta</h1>
# <!-- --><!-- --><!-- --><!-- --> </div>
# <!-- --> <div class="text-body-medium break-words" data-generated-suggestion-target="urn:li:fsu_profileActionDelegate:97633891">
#       CO-Founder at boAt
#     </div>
# <!-- --><!-- --><!-- --> </div>

# %%
name_loc = intro.find("h1")

name = name_loc.get_text().strip()

works_at_loc = intro.find("div", {'class': 'text-body-medium'})

works_at = works_at_loc.get_text().strip()
print(works_at_loc)

location_loc = intro.find_all("span", {'class': 'text-body-small'})

print("Name -->", name,
	"\nWorks At -->", works_at,
	"\nLocation -->", location_loc)
# Out:
# <div class="text-body-medium break-words" data-generated-suggestion-target="urn:li:fsu_profileActionDelegate:97633891">
#       CO-Founder at boAt
#     </div>
# Name --> Sameer Mehta
# Works At --> CO-Founder at boAt
# Location --> []

# %%
experience = soup.find("div", {"class": "pvs-list__outer-container"}).find('ul', {'class': 'pvs-list'})

print(experience)
# Out:
# <ul class="pvs-list">
# <li class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column pvs-list--ignore-first-item-top-padding">
# <div class="pvs-mini-update pvs-list__item--no-padding-in-columns display-flex flex-column">
# <!-- --> <a aria-label="View full post. Sameer Mehta posted this • 1w" class="app-aware-link feed-mini-update-optional-navigation-context-wrapper" data-test-app-aware-link="" href="https://www.linkedin.com/feed/update/urn:li:activity:7074770097860415489?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7074770097860415489%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29" tabindex="0">
# <div class="pt1 ph4 t-12 t-black--light">
# <span class="feed-mini-update-contextual-description__text">
# <span aria-hidden="true"><strong><!-- -->Sameer Mehta<!-- --></strong><span class="white-space-pre"> </span>posted this • 1w<!-- --></span><span class="visually-hidden"><!-- -->1w<!-- --></span>
# </span>
# </div>
# </a>
# <div class="display-flex flex-row">
# <a aria-label="View full post. Image" class="app-aware-link pl4 pv2 pr1 feed-mini-update-optional-navigation-context-wrapper" data-test-app-aware-link="" href="https://www.linkedin.com/feed/update/urn:li:activity:7074770097860415489?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7074770097860415489%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29" tabindex="0">
# <div class="relative">
# <span class="feed-mini-update-commentary__video-icon">
# <svg aria-hidden="true" class="feed-mini-update-commentary__video-icon-svg" data-supported-dps="16x16" data-test-icon="play-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <!-- -->
# <use height="16" href="#play-small" width="16"></use>
# </svg>
# </span>
# <div class="ivm-image-view-model">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <!-- --> <img alt="" class="ivm-view-attr__img--centered feed-mini-update-commentary__image evi-image lazy-image ember-view" height="64" id="ember101" loading="lazy" src="https://media.licdn.com/dms/image/D4D05AQF-mxkrqHvaag/feedshare-thumbnail_720_1280/0/1686756621735?e=1688234400&amp;v=beta&amp;t=gOBAXg3EMVNW7AeFVwtuxD6Z9h-oTXa8_98al881G5c" width="64"/>
# </div>
# </div>
# </div>
# </a>
# <a aria-label="View full post. At boAt we believe that we can be truly world class , we can compete with the best
# This is our 2nd product in the nirvana series , we delivered the best battery back up on Tws ear buds  and now the first Dolby enabled neck band
#
# More excitement in the offing
#
# #dolby Aman Gupta" class="app-aware-link pr4 pb2 flex-1 pl2 pt2 feed-mini-update-optional-navigation-context-wrapper" data-test-app-aware-link="" href="https://www.linkedin.com/feed/update/urn:li:activity:7074770097860415489?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7074770097860415489%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29" tabindex="0">
# <!-- --> <div class="inline-show-more-text inline-show-more-text--is-collapsed inline-show-more-text--is-collapsed-with-line-clamp m0 break-words t-14 t-black" style="-webkit-line-clamp:3;" tabindex="-1">
# <span dir="ltr"><!-- -->At boAt we believe that we can be truly world class , we can compete with the best<span class="white-space-pre"> </span><br/><!-- -->This is our 2nd product in the nirvana series , we delivered the best battery back up on Tws ear buds  and now the first Dolby enabled neck band<span class="white-space-pre"> </span><br/><br/><!-- -->More excitement in the offing<!-- --><br/><br/><a class="ember-view inline-block" data-test="hash" href="/feed/hashtag/dolby/" id="ember102">
# <span class="visually-hidden">hashtag</span>
# <span><span aria-hidden="true">#</span>dolby</span>
# </a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/ACoAAAMkc8kBdWKTLlR2OReZqTQBn4_3fRYgRlY" target="_self"></a><a class="ember-view" href="/in/aman-gupta-7217a515/" id="ember103"><!-- -->Aman Gupta<!-- --></a></span>
# <span class="inline-show-more-text__link-container-collapsed">
# <!-- --> <button aria-expanded="false" class="inline-show-more-text__button inline-show-more-text__button--light link" role="link" type="button">
#           …show more
#         </button>
# </span>
# <!-- --></div>
# </a>
# </div>
# <!-- -->
# <ul class="social-details-social-counts b0 m0 ph4 pv3">
# <li class="social-details-social-counts__item social-details-social-counts__reactions social-details-social-counts__reactions--with-social-proof">
# <button aria-label="1,866 reactions" class="t-black--light display-flex social-details-social-counts__count-value t-12 hoverable-link-text" type="button">
# <img alt="like" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--0 reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="LIKE" src="https://static.licdn.com/sc/h/8ekq8gho1ruaf8i7f86vd1ftt"/>
# <img alt="love" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--1 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="EMPATHY" src="https://static.licdn.com/sc/h/cpho5fghnpme8epox8rdcds22"/>
# <img alt="celebrate" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--2 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="PRAISE" src="https://static.licdn.com/sc/h/b1dl5jk88euc7e9ri50xy5qo8"/>
# <span aria-hidden="true" class="social-details-social-counts__reactions-count">
# 1,866          </span>
# </button>
# </li>
# <li class="social-details-social-counts__item social-details-social-counts__comments social-details-social-counts__item--with-social-proof">
# <button aria-label="65 comments" class="t-black--light social-details-social-counts__count-value t-12 hoverable-link-text" role="link" type="button">
# <span aria-hidden="true">
#               65 comments
#           </span>
# </button>
# </li>
# <li class="social-details-social-counts__item social-details-social-counts__item--with-social-proof">
# <button aria-label="10 reposts" class="ember-view t-black--light t-12 hoverable-link-text" id="ember104">
# <span aria-hidden="true">
#             10 reposts
#           </span>
# </button>
# </li>
# <!-- --></ul>
# <div>
# <div class="ember-view" id="ember105"><!-- --></div>
# </div>
# <div class="ember-view" id="ember106"><!-- --></div>
# <!-- -->
# </div>
# </li>
# <li class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column pvs-list--ignore-first-item-top-padding">
# <div class="pvs-mini-update pvs-list__item--no-padding-in-columns display-flex flex-column">
# <!-- --> <a aria-label="View full post. Sameer Mehta posted this • 1mo" class="app-aware-link feed-mini-update-optional-navigation-context-wrapper" data-test-app-aware-link="" href="https://www.linkedin.com/feed/update/urn:li:activity:7062374653285081089?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7062374653285081089%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29" tabindex="0">
# <div class="pt1 ph4 t-12 t-black--light">
# <span class="feed-mini-update-contextual-description__text">
# <span aria-hidden="true"><strong><!-- -->Sameer Mehta<!-- --></strong><span class="white-space-pre"> </span>posted this • 1mo<!-- --></span><span class="visually-hidden"><!-- -->1mo<!-- --></span>
# </span>
# </div>
# </a>
# <div class="display-flex flex-row">
# <!-- --> <a aria-label="View full post. boAt is a company with a strong vision, aggressive goals, and an incredibly capable team focussed on creating cutting-edge hearable and wearable products. boAt Labs is a testament to our commitment to developing truly innovative technologies in India for the world which accentuates user experience. We are closely working with global technology companies like Qualcomm, Dolby, Dirac, Mimi, CEVA and more which offer innovative technologies that will help facilitate and accelerate our efforts with a specific focus on designing &amp; engineering in India thus elevating user experience.”
#
# Happy Technology Day to all the technovators!!
#
# boAt Lifestyle Aman Gupta" class="app-aware-link pr4 pb2 flex-1 pl4 pt2 feed-mini-update-optional-navigation-context-wrapper" data-test-app-aware-link="" href="https://www.linkedin.com/feed/update/urn:li:activity:7062374653285081089?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7062374653285081089%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29" tabindex="0">
# <!-- --> <div class="inline-show-more-text inline-show-more-text--is-collapsed inline-show-more-text--is-collapsed-with-line-clamp m0 break-words t-14 t-black" style="-webkit-line-clamp:3;" tabindex="-1">
# <span dir="ltr"><!-- -->boAt is a company with a strong vision, aggressive goals, and an incredibly capable team focussed on creating cutting-edge hearable and wearable products. boAt Labs is a testament to our commitment to developing truly innovative technologies in India for the world which accentuates user experience. We are closely working with global technology companies like Qualcomm, Dolby, Dirac, Mimi, CEVA and more which offer innovative technologies that will help facilitate and accelerate our efforts with a specific focus on designing &amp; engineering in India thus elevating user experience.”<!-- --><br/><br/><!-- -->Happy Technology Day to all the technovators!!<!-- --><br/><br/><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/boat-lifestyle/" target="_self"><span><!-- -->boAt Lifestyle<!-- --></span></a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/ACoAAAMkc8kBdWKTLlR2OReZqTQBn4_3fRYgRlY" target="_self"></a><a class="ember-view" href="/in/aman-gupta-7217a515/" id="ember108"><!-- -->Aman Gupta<!-- --></a></span>
# <span class="inline-show-more-text__link-container-collapsed">
# <!-- --> <button aria-expanded="false" class="inline-show-more-text__button inline-show-more-text__button--light link" role="link" type="button">
#           …show more
#         </button>
# </span>
# <!-- --></div>
# </a>
# </div>
# <!-- -->
# <ul class="social-details-social-counts b0 m0 ph4 pv3">
# <li class="social-details-social-counts__item social-details-social-counts__reactions social-details-social-counts__reactions--with-social-proof">
# <button aria-label="919 reactions" class="t-black--light display-flex social-details-social-counts__count-value t-12 hoverable-link-text" type="button">
# <img alt="like" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--0 reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="LIKE" src="https://static.licdn.com/sc/h/8ekq8gho1ruaf8i7f86vd1ftt"/>
# <img alt="celebrate" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--1 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="PRAISE" src="https://static.licdn.com/sc/h/b1dl5jk88euc7e9ri50xy5qo8"/>
# <img alt="love" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--2 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="EMPATHY" src="https://static.licdn.com/sc/h/cpho5fghnpme8epox8rdcds22"/>
# <span aria-hidden="true" class="social-details-social-counts__reactions-count">
# 919          </span>
# </button>
# </li>
# <li class="social-details-social-counts__item social-details-social-counts__comments social-details-social-counts__item--with-social-proof">
# <button aria-label="46 comments" class="t-black--light social-details-social-counts__count-value t-12 hoverable-link-text" role="link" type="button">
# <span aria-hidden="true">
#               46 comments
#           </span>
# </button>
# </li>
# <!-- -->
# <!-- --></ul>
# <div>
# <div class="ember-view" id="ember109"><!-- --></div>
# </div>
# <div class="ember-view" id="ember110"><!-- --></div>
# <!-- -->
# </div>
# </li>
# </ul>

# %%
li_tags = experience.find('div')

a_tags = li_tags.find("a")

job_title = a_tags.find("h3").get_text().strip()

print(job_title)

company_name = a_tags.find_all("p")[1].get_text().strip()
print(company_name)

joining_date = a_tags.find_all("h4")[0].find_all("span")[1].get_text().strip()

employment_duration = a_tags.find_all("h4")[1].find_all(
	"span")[1].get_text().strip()

print(joining_date + ", " + employment_duration)
# Out:
# <a aria-label="View full post. Sameer Mehta posted this • 1w" class="app-aware-link feed-mini-update-optional-navigation-context-wrapper" data-test-app-aware-link="" href="https://www.linkedin.com/feed/update/urn:li:activity:7074770097860415489?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7074770097860415489%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29" tabindex="0">
# <div class="pt1 ph4 t-12 t-black--light">
# <span class="feed-mini-update-contextual-description__text">
# <span aria-hidden="true"><strong><!-- -->Sameer Mehta<!-- --></strong><span class="white-space-pre"> </span>posted this • 1w<!-- --></span><span class="visually-hidden"><!-- -->1w<!-- --></span>
# </span>
# </div>
# </a>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 7
#       5 a_tags = li_tags.find("a")
#       6 print(a_tags)
# ----> 7 job_title = a_tags.find("h3").get_text().strip()
#       9 print(job_title)
#      11 company_name = a_tags.find_all("p")[1].get_text().strip()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
jobs = driver.find_element(By.XPATH, "//a[@data-link-to='jobs']/span")

jobs.click()

# %%
job_src = driver.page_source

soup = BeautifulSoup(job_src, 'lxml')

# %%
jobs_html = soup.find_all('a', {'class': 'job-card-list__title'})

job_titles = []

for title in jobs_html:
	job_titles.append(title.text.strip())

print(job_titles)
